# %%
import pandas as pd
import numpy as np


poke = pd.read_csv("./datasets/pokemon_data.csv")

# %%
poke[-5:]
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# Get gen 6 pokemons

poke[poke.Generation == 6]
# Out:
#        #                 Name   Type 1    Type 2  HP  Attack  Defense  \
# 718  650              Chespin    Grass       NaN  56      61       65
# 719  651            Quilladin    Grass       NaN  61      78       95
# 720  652           Chesnaught    Grass  Fighting  88     107      122
# 721  653             Fennekin     Fire       NaN  40      45       40
# 722  654              Braixen     Fire       NaN  59      59       58
# ..   ...                  ...      ...       ...  ..     ...      ...
# 795  719              Diancie     Rock     Fairy  50     100      150
# 796  719  DiancieMega Diancie     Rock     Fairy  50     160      110
# 797  720  HoopaHoopa Confined  Psychic     Ghost  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic      Dark  80     160       60
# 799  721            Volcanion     Fire     Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 718       48       45     38           6      False
# ...

# %%
poke[(poke.Legendary) & (poke['Type 1'] == "Fire")]['Name']
# Out:
# 158      Moltres
# 263        Entei
# 270        Ho-oh
# 542      Heatran
# 799    Volcanion
# Name: Name, dtype: object

# %%
# Finding specific element by text

poke.loc[poke['Type 1'] == "Ice"]
# Out:
#        #               Name Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 133  124               Jynx    Ice  Psychic   65      50       35      115
# 156  144           Articuno    Ice   Flying   90      85      100       95
# 238  220             Swinub    Ice   Ground   50      50       40       30
# 239  221          Piloswine    Ice   Ground  100     100       80       60
# 243  225           Delibird    Ice   Flying   45      55       45       65
# 257  238           Smoochum    Ice  Psychic   45      30       15       85
# 395  361            Snorunt    Ice      NaN   50      50       50       50
# 396  362             Glalie    Ice      NaN   80      80       80       80
# 397  362  GlalieMega Glalie    Ice      NaN   80     120       80      120
# 398  363             Spheal    Ice    Water   70      40       50       55
# 399  364             Sealeo    Ice    Water   90      60       70       75
# ...

# %%
# Sorting

poke.sort_values(['Attack', 'HP'], ascending=True)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 488  440                  Happiny   Normal       NaN  100       5        5
# 121  113                  Chansey   Normal       NaN  250       5        5
# 139  129                 Magikarp    Water       NaN   20      10       55
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 261  242                  Blissey   Normal       NaN  255      10       10
# ..   ...                      ...      ...       ...  ...     ...      ...
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# Making Changes to the data

# Add Total
poke['Total'] = np.sum(poke.iloc[:, 4:10], axis=1)

poke
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
# Saving csv

poke.to_csv("./datasets/modified.csv")


# No index
poke.to_csv("./datasets/modified.csv", index=False)


poke[:10]
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# ...

# %%
# Filtering Data

# poke[poke['Type 1'] == 'Fire'].iloc[3]

# poke.loc[poke['Name'].str.isnumeric]

# poke['Type 1'].str.contains('fire', regex=True, case=False)
poke
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
# Conditional Changes

# poke.loc[poke['Type 1'].str.contains('Flame'), 'Type 1'] = 'Fire'

poke.loc[:, 'Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
# Aggregate Stats
poke = pd.read_csv('./datasets/modified.csv')


pokearr = poke.drop(columns=['Name', 'Type 2', 'Legendary', 'Generation'])
# pokearr
pokearr.groupby(['Type 1']).count().sort_values('#', ascending=False)['']
# Out:
#             #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# Type 1
# Water     112  112     112      112      112      112    112    112
# Normal     98   98      98       98       98       98     98     98
# Grass      70   70      70       70       70       70     70     70
# Bug        69   69      69       69       69       69     69     69
# Psychic    57   57      57       57       57       57     57     57
# Fire       52   52      52       52       52       52     52     52
# Electric   44   44      44       44       44       44     44     44
# Rock       44   44      44       44       44       44     44     44
# Ground     32   32      32       32       32       32     32     32
# Dragon     32   32      32       32       32       32     32     32
# Ghost      32   32      32       32       32       32     32     32
# Dark       31   31      31       31       31       31     31     31
# Poison     28   28      28       28       28       28     28     28
# ...
